# %% [markdown]
# # ***Engr.Muhammad Javed***

# %% [markdown]
# ## **Decision Tree Entropy**

# %% [markdown]
# # *Importing Required Libraries*

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier , plot_tree
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix

# %% [markdown]
# # *Loading the Dataset*

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sharmaroshan/Heart-UCI-Dataset/master/heart.csv')

# %% [markdown]
# ## *Show Dataset*

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## *Viewing Statistical Summary of the Dataset*

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ## *Checking Dataset Information*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ## *Splitting Features and Target Variable*

# %%
x = data.drop(["target"] , axis = 1)
y = data["target"]

# %% [markdown]
# ## *Splitting the Dataset into Training and Testing Sets*

# %%
X_train , X_test , Y_train , Y_test = train_test_split( x, y , random_state= 42 , test_size= 0.2)

# %% [markdown]
# ## *Model Training using Decision Tree Classifier (Entropy)*

# %%
model_entropy = DecisionTreeClassifier(criterion="entropy" , min_samples_leaf=5 , max_depth=5 , random_state=42)
model_entropy.fit(X_train , Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=5,
#                        random_state=42)

# %%
model_entropy.score(X_test , Y_test)*100
# Out:
# 77.04918032786885

# %% [markdown]
# ## *Checking for Overfitting or Underfitting*

# %%
print(model_entropy.score(X_train , Y_train)*100)
print(model_entropy.score(X_test , Y_test)*100)
# Out:
# 85.9504132231405
# 77.04918032786885

# %%
for i in range (1,20):
    dt1 = DecisionTreeClassifier(max_depth=i)
    dt1.fit(X_train , Y_train)
    print(dt1.score(X_train , Y_train) , dt1.score(X_test , Y_test))

# %% [markdown]
# ## *Making Predictions on the Test Set*

# %%
y_pred_entropy = model_entropy.predict(X_test)

# %% [markdown]
# ## *Evaluating Model Performance*

# %%
print("\n Entropy Tree")
print(accuracy_score(Y_test , y_pred_entropy))
print(classification_report(Y_test , y_pred_entropy))
# Out:
#  Entropy Tree
# 0.7704918032786885
#               precision    recall  f1-score   support
#
#            0       0.70      0.90      0.79        29
#            1       0.88      0.66      0.75        32
#
#     accuracy                           0.77        61
#    macro avg       0.79      0.78      0.77        61
# weighted avg       0.79      0.77      0.77        61

# %% [markdown]
# ## *Visualizing the Confusion Matrix*

# %%
plt.title("Confusion Matrix - Entropy")
sn.heatmap(confusion_matrix(Y_test , y_pred_entropy) , annot= True)
plt.show()

# %% [markdown]
# ## *Visualizing the Decision Tree*

# %%
plt.figure(figsize=(20,20))
plt.title("Decision Tree Entropy")
plot_tree(model_entropy , feature_names=x.columns , class_names=["No Disease" , "Disease"])
plt.show()
plt.savefig("Decision Tree Entropy.jpg")
